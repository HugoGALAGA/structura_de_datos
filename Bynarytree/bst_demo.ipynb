# %% [markdown]
# ### Parte 3
# ---
#
# < Hugo Jonathan Daniel Galina Puac >
# < 20240566 >

# %%
from bst import BinarySearchTree

# %%
tree = BinarySearchTree()

# %%
vals = [28, 52, 8, 31, 27, 72, 69, 91, 85, 29, 25, 38, 80, 47, 7, 48, 56, 63, 86, 40, 99, 10, 58, 67, 50 ] # Agregar 25 valores aleatorios que permitan demostrar los 3 casos de delete

for val in vals:
    tree.insert(val)

# %%
tree.print_pretty()
# Out:
#   ______28_______________
#  /                       \
#  8_____       __________52___________
# /      \     /                       \
# 7     27    31_                     72_______
#      /     /   \                   /         \
#     25    29  38___         ______69      __91_
#    /               \       /             /     \
#   10              47_     56___         85_   99
#                  /   \         \       /   \
#                 40  48_       63_     80  86
#                        \     /   \
#                       50    58  67

# %% [markdown]
# ## Delete - caso no. 1 (Delete leaf node)

# %%
tree.delete(50)
tree.print_pretty()
# Out:
#   ______28_____________
#  /                     \
#  8_____       ________52___________
# /      \     /                     \
# 7     27    31_                   72_______
#      /     /   \                 /         \
#     25    29  38___       ______69      __91_
#    /               \     /             /     \
#   10              47_   56___         85_   99
#                  /   \       \       /   \
#                 40  48      63_     80  86
#                            /   \
#                           58  67

# %%
# TODO: demostrar que el método de delete() creado funciona para el caso #1

# %% [markdown]
# ## Delete - caso no. 2 (un hijo)

# %%
tree.delete(25)
tree.print_pretty()
# Out:
#   ____28_____________
#  /                   \
#  8___       ________52___________
# /    \     /                     \
# 7   27    31_                   72_______
#    /     /   \                 /         \
#   10    29  38___       ______69      __91_
#                  \     /             /     \
#                 47_   56___         85_   99
#                /   \       \       /   \
#               40  48      63_     80  86
#                          /   \
#                         58  67

# %%
# TODO: demostrar que el método de delete() creado funciona para el caso #2

# %% [markdown]
# ## Delete - caso no. 3

# %%
tree.delete(31)
tree.print_pretty()
# Out:
#   ____28___________
#  /                 \
#  8___     ________52___________
# /    \   /                     \
# 7   27  29_                   72_______
#    /       \                 /         \
#   10      38___       ______69      __91_
#                \     /             /     \
#               47_   56___         85_   99
#              /   \       \       /   \
#             40  48      63_     80  86
#                        /   \
#                       58  67

# %%
# TODO: demostrar que el método de delete() creado funciona para el caso #3

# %% [markdown]
# ---
